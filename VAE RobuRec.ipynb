# %%
import tensorflow as tf
from ML100kPP import InteractionMatrix
import pandas as pd
from MovieLens1MPreprocessing import RatingMatrix_ML1M

# %%
ML_100K_ratingMatrix = InteractionMatrix('Drama','Comedy')#change the inputs here to change the two domains

RatingMatrix = ML_100K_ratingMatrix.RatingMatrix
domainARatingMatrix = ML_100K_ratingMatrix.domainARatingMatrix
domainBRatingMatrix = ML_100K_ratingMatrix.domainBRatingMatrix

# %%
from sklearn.model_selection import train_test_split

# %%
DomainA_train_1, DomainA_test_1 = train_test_split(domainARatingMatrix, test_size = 0.3, random_state = 0)
DomainB_train_1, DomainB_test_1 = train_test_split(domainBRatingMatrix, test_size = 0.3, random_state = 0)

DomainA_train_2 = DomainA_train_1.applymap(lambda x: 1 if x != 0 else 0 )
DomainB_train_2 = DomainB_train_1.applymap(lambda x: 1 if x != 0 else 0 )
DomainA_test_2 = DomainA_test_1.applymap(lambda x: 1 if x != 0 else 0 )
DomainB_test_2 = DomainB_test_1.applymap(lambda x: 1 if x != 0 else 0 )

domainA_train = tf.cast(DomainA_train_2, tf.float32)
domainB_train = tf.cast(DomainB_train_2, tf.float32)
domainA_test = tf.cast(DomainA_test_2, tf.float32)
domainB_test = tf.cast(DomainB_test_2, tf.float32)

# %%
ML_1M_ratingMatrix = RatingMatrix_ML1M('Drama', 'Comedy')

Rating_matrix_ML1M = ML_1M_ratingMatrix.ratingMatrix
domainARatingMatrix_ML1M = ML_1M_ratingMatrix.domainARatingMatrix
domainBRatingMatrix_ML1M = ML_1M_ratingMatrix.domainBRatingMatrix

# %%
DomainA_train_1_ML1M, DomainA_test_1_ML1M = train_test_split(domainARatingMatrix_ML1M, test_size = 0.2, 
                                                             random_state = 0)
DomainB_train_1_ML1M, DomainB_test_1_ML1M = train_test_split(domainBRatingMatrix_ML1M, test_size = 0.2,
                                                             random_state = 0)

DomainA_train_2_ML1M = DomainA_train_1_ML1M.applymap(lambda x: 1 if x != 0 else 0 )
DomainB_train_2_ML1M = DomainB_train_1_ML1M.applymap(lambda x: 1 if x != 0 else 0 )
DomainA_test_2_ML1M = DomainA_test_1_ML1M.applymap(lambda x: 1 if x != 0 else 0 )
DomainB_test_2_ML1M = DomainB_test_1_ML1M.applymap(lambda x: 1 if x != 0 else 0 )

domainA_train_ML1M = tf.cast(DomainA_train_2_ML1M, tf.float32)
domainB_train_ML1M = tf.cast(DomainB_train_2_ML1M, tf.float32)
domainA_test_ML1M = tf.cast(DomainA_test_2_ML1M, tf.float32)
domainB_test_ML1M = tf.cast(DomainB_test_2_ML1M, tf.float32)

# %%
def kl_loss(mu, sigma):
    return 0.5*tf.reduce_mean(tf.reduce_sum(1+ tf.math.log(tf.square(sigma)) - tf.square(mu) - tf.square(sigma)
            , axis = 1))

# %%
def loss_reconstruct(matrix, recon_matrix):
        
    log_softmax_matrix = tf.nn.log_softmax(recon_matrix)
    
    nll = -tf.reduce_mean(tf.reduce_sum(log_softmax_matrix * matrix, axis = -1))
      
    return nll

# %%
import tensorflow as tf 
from tensorflow.keras.layers import Dense

# %%
class VAE(tf.keras.Model):
    
    def __init__(self, encode_dim, share_dim, z_dim, decode_dim, interaction_matrix, lambda1, lambda2, weight_decay):
        
        super().__init__()
        
        decode_dim.append(int(interaction_matrix.shape[1]))
        
        first_encode_dim = []
        
        first_encode_dim.append(int(interaction_matrix.shape[1]))
        
        encode_dim = first_encode_dim + encode_dim
        
        self.regularizer = tf.keras.regularizers.L2(weight_decay)
        
        self.lambda1 = lambda1
        
        self.lambda2 = lambda2
        
        self.eps = 1e-10
        
        self.encode_layers = []
        
        self.decode_layers = []
        
        self.share_layers_encoder = []
        
        self.share_layers_decoder = [] 
        
        for i in range (len(encode_dim)):#Encoding the data 
            
            self.encode_layers.append(Dense(int(encode_dim[i]), kernel_regularizer = self.regularizer,
            trainable = True))
            
            self.encode_layers.append(tf.keras.layers.LeakyReLU(alpha = 0.5))
            
        for j in range(len(share_dim)):#the share layer
             
            self.share_layers_encoder.append(Dense(int(share_dim[j]), kernel_regularizer = self.regularizer,
            trainable = True))
            
            self.share_layers_encoder.append(tf.keras.layers.LeakyReLU(alpha = 0.5))
        
        #the latent distrubution generator #Note z_dim controls the number of columns in the latent distribution  
        self.z_mu_layer = Dense(z_dim, activation = 'tanh', kernel_regularizer = self.regularizer)
        
        self.z_sigma_layer = Dense(z_dim, activation = 'tanh', kernel_regularizer = self.regularizer)
        
        for k in range(len(share_dim)):#the share layer
             
            self.share_layers_decoder.append(Dense(int(share_dim[k]), kernel_regularizer = self.regularizer,
            trainable = True))
            
            self.share_layers_decoder.append(tf.keras.layers.LeakyReLU(alpha = 0.5))     
        
        for l in range(len(decode_dim)): #The decoder/generator
            
            if l != len(decode_dim)-1:
            
                self.decode_layers.append(Dense(int(decode_dim[l]), kernel_regularizer = self.regularizer
                        ,trainable = True))
            
                self.decode_layers.append(tf.keras.layers.LeakyReLU(alpha = 0.5)) 
                
            else:

                self.decode_layers.append(Dense(int(decode_dim[l]), activation = 'sigmoid',
                    kernel_regularizer = self.regularizer,trainable = True))
            
            #Note the last value of decode_dim controls the number of columns in the reconstructed matrix   
        
    def call (self, interaction_matrix):
                
        for encode_layer in self.encode_layers:
            
            interaction_matrix = encode_layer(interaction_matrix)
        
        for share_layer_encoder in self.share_layers_encoder:
            
            interaction_matrix = share_layer_encoder(interaction_matrix)
        
        self.z_mean = self.z_mu_layer(interaction_matrix)
        
        self.z_sd = self.z_sigma_layer(interaction_matrix)
        
        e = tf.random.normal(tf.shape(self.z_sd))
            
        interaction_matrix = self.z_mean + tf.sqrt(tf.maximum(tf.exp(self.z_sd), self.eps)) * e
        
        z = tf.identity(interaction_matrix)#Z_A or Z_B 
        
        for share_layer_decoder in self.share_layers_decoder[::-1]:
            
            interaction_matrix = share_layer_decoder(interaction_matrix)
        
        for decode_layer in self.decode_layers:

            interaction_matrix = decode_layer(interaction_matrix)
        
        self.interaction_matrix_recon = tf.identity(interaction_matrix)
        
        return interaction_matrix, z
    
    def vae_loss(self, interaction_matrix):
        
        loss_kl = self.lambda1 * kl_loss(self.z_mean, self.z_sd)
    
        reconstruct_loss = self.lambda2 * loss_reconstruct(interaction_matrix, self.interaction_matrix_recon)
    
        loss = loss_kl + reconstruct_loss
    
        return loss 
    
    def get_config(self):
        
        configuration = super(cycle_consistency, self).get_config()
        
        configuration.update({
            'lambda1':self.lambda1,'lambda2':self.lambda2,'regularizer':self.regularizer,'eps':self.eps,
            'encode_layers':[encode_layer.get_config() for encode_layer in self.encode_layers],
            'share_layers_encoder':[e_share_layer.get_config() for e_share_layer in self.share_layers_encoder],
            'decode_layers':[decode_layer.get_config() for decode_layer in self.decode_layers],
            'share_layers_decoder':[d_layer_decoder.get_config() for d_layer_decoder in self.share_layers_decoder],     
        })
        
        return configuration

# %%
def load_and_test(domainA_test, domainB_test, file_path_VAE_A, file_path_VAE_B):

    VAE_A = tf.saved_model.load(file_path_VAE_A)
    
    VAE_B = tf.saved_model.load(file_path_VAE_B)
    
    y_AA = tf.zeros(domainA_test.shape, dtype = tf.float32)
    
    y_BB = tf.zeros(domainB_test.shape, dtype = tf.float32)
    
    i = 0
    
    for user_vector_A in domainA_test:
    
        user_vector_A = tf.reshape(user_vector_A, (1,domainA_test.shape[1]))
    
        x_AA,Z_A = VAE_A(user_vector_A)
        
        y_AA = tf.tensor_scatter_nd_update(y_AA, [[i]], x_AA)
        
        i += 1 
        
    j = 0
    
    for user_vector_B in domainB_test:
    
        user_vector_B = tf.reshape(user_vector_B, (1,domainB_test.shape[1]))
    
        x_BB,Z_B = VAE_B(user_vector_B)
        
        y_BB = tf.tensor_scatter_nd_update(y_BB, [[j]], x_BB)
        
        j += 1
    
    return y_AA, y_BB

# %%
def build_and_train_Model(encode_dim_A, share_dim, z_dim, decode_dim_A, training_dataset_A, encode_dim_B,
                        decode_dim_B, training_dataset_B, weight_decay, lambda1, lambda2, learning_rate_A, 
                        learning_rate_B, num_epochs_A, num_epochs_B, batch_size_A, batch_size_B,
                        file_path_VAE_A,file_path_VAE_B):
    
    #defining the VAEs for domain A and B 
    
    VAE_A = VAE(encode_dim_A, share_dim, z_dim, decode_dim_A, training_dataset_A, lambda1, lambda2, weight_decay)
    
    VAE_B = VAE(encode_dim_B, share_dim, z_dim, decode_dim_B, training_dataset_B, lambda1, lambda2, weight_decay)
    
    #training VAE_A, VAE_B
    
    optimizer_A = tf.keras.optimizers.legacy.Adam(learning_rate_A)
    
    number_of_batches_A = len(training_dataset_A)//batch_size_A
    
    number_of_batches_B = len(training_dataset_B)//batch_size_B
    
    x1 = []
    y1 = []
    
    print("VAE_A training: \n")
    
    for epoch in range(num_epochs_A):
        
        print('epoch number: ', epoch + 1)
        
        x1.append(epoch + 1)
        
        for batch_number in range(number_of_batches_A):
            
            start_id = batch_number * batch_size_A
            
            end_id = start_id + batch_size_A
            
            if end_id > len(training_dataset_A):
                
                end_id = len(training_dataset_A) - 1
            
            batch_A = training_dataset_A[start_id : end_id]
            
            with tf.GradientTape() as tape:
                y_AA = VAE_A(batch_A)
                vae_loss = VAE_A.vae_loss(batch_A)
                
            gradients = tape.gradient(vae_loss, VAE_A.trainable_variables)
            
            optimizer_A.apply_gradients(zip(gradients, VAE_A.trainable_variables))
            
        y1.append(vae_loss)    
        
        print('Training Set VAE loss: ', vae_loss)
        
    optimizer_B = tf.keras.optimizers.legacy.Adam(learning_rate_B)
    
    x2 = []
    y2 = []
    
    print("\n VAE_B training: \n")
    
    for epoch in range(num_epochs_B):
        
        print('epoch number: ', epoch + 1)
        
        x2.append(epoch+1)
        
        for batch_number in range(number_of_batches_B):
            
            start_id = batch_number * batch_size_B
            
            end_id = start_id + batch_size_B
            
            if end_id > len(training_dataset_B):
                
                end_id = len(training_dataset_B) - 1
            
            batch_B = training_dataset_B[start_id : end_id]

            with tf.GradientTape() as tape:
                
                y_BB = VAE_B(batch_B)
                vae_loss = VAE_B.vae_loss(batch_B)
                
            gradients = tape.gradient(vae_loss, VAE_B.trainable_variables)
            
            optimizer_B.apply_gradients(zip(gradients, VAE_B.trainable_variables))
            
        y2.append(vae_loss)    
        
        print('Training Set VAE loss: ', vae_loss)
        
    tf.saved_model.save(VAE_A, file_path_VAE_A)
        
    tf.saved_model.save(VAE_B, file_path_VAE_B)
        
    return x1,y1,x2,y2

# %%
x1,y1,x2,y2= build_and_train_Model([200], [100], 50, [200] , domainA_train, [200], [200], 
                     domainB_train, 0.01, 0.1, 0.2, 1e-5, 1e-5 , 200, 200, 30, 30, 
                    '/Users/ahmedaly/Desktop/Final_Model/VAE_A', '/Users/ahmedaly/Desktop/Final_Model/VAE_B')

y_AA, y_BB = load_and_test(domainA_test, domainB_test, '/Users/ahmedaly/Desktop/Final_Model/VAE_A', 
              '/Users/ahmedaly/Desktop/Final_Model/VAE_B')

#ML1M settings
#x1,y1,x2,y2 = build_and_train_Model([200], [100], 50, [200] , domainA_train_ML1M, [100], [200], 
                     # domainB_train_ML1M, 0.01, 0.1, 0.2, 1e-4, 1e-4 , 30, 20, 30, 30,
                     #'/Users/ahmedaly/Desktop/Final_Model/VAE_A', '/Users/ahmedaly/Desktop/Final_Model/VAE_B') 

#ML100K settings
#x1,y1,x2,y2= build_and_train_Model([200], [100], 50, [200] , domainA_train, [200], [200], 
                     # domainB_train, 0.01, 0.1, 0.2, 1e-5, 1e-5 , 200, 200, 30, 30, 
                      #'/Users/ahmedaly/Desktop/Final_Model/VAE_A', '/Users/ahmedaly/Desktop/Final_Model/VAE_B')
# Out:
# VAE_A training:
#
# epoch number:  1
# Training Set VAE loss:  tf.Tensor(43.604, shape=(), dtype=float32)
# epoch number:  2
# Training Set VAE loss:  tf.Tensor(43.558273, shape=(), dtype=float32)
# epoch number:  3
# Training Set VAE loss:  tf.Tensor(43.559116, shape=(), dtype=float32)
# epoch number:  4
# Training Set VAE loss:  tf.Tensor(43.504074, shape=(), dtype=float32)
# epoch number:  5
# Training Set VAE loss:  tf.Tensor(43.526756, shape=(), dtype=float32)
# epoch number:  6
# Training Set VAE loss:  tf.Tensor(43.533764, shape=(), dtype=float32)
# epoch number:  7
# Training Set VAE loss:  tf.Tensor(43.50321, shape=(), dtype=float32)
# epoch number:  8
# Training Set VAE loss:  tf.Tensor(43.42007, shape=(), dtype=float32)
# epoch number:  9
# Training Set VAE loss:  tf.Tensor(43.41777, shape=(), dtype=float32)
# epoch number:  10
# Training Set VAE loss:  tf.Tensor(43.360268, shape=(), dtype=float32)
# epoch number:  11
# Training Set VAE loss:  tf.Tensor(43.355927, shape=(), dtype=float32)
# epoch number:  12
# Training Set VAE loss:  tf.Tensor(43.32208, shape=(), dtype=float32)
# epoch number:  13
# Training Set VAE loss:  tf.Tensor(43.25892, shape=(), dtype=float32)
# epoch number:  14
# Training Set VAE loss:  tf.Tensor(43.323864, shape=(), dtype=float32)
# epoch number:  15
# Training Set VAE loss:  tf.Tensor(43.235497, shape=(), dtype=float32)
# epoch number:  16
# Training Set VAE loss:  tf.Tensor(43.248497, shape=(), dtype=float32)
# epoch number:  17
# Training Set VAE loss:  tf.Tensor(43.2312, shape=(), dtype=float32)
# epoch number:  18
# Training Set VAE loss:  tf.Tensor(43.163765, shape=(), dtype=float32)
# epoch number:  19
# Training Set VAE loss:  tf.Tensor(43.112083, shape=(), dtype=float32)
# epoch number:  20
# Training Set VAE loss:  tf.Tensor(43.062763, shape=(), dtype=float32)
# epoch number:  21
# Training Set VAE loss:  tf.Tensor(43.029, shape=(), dtype=float32)
# epoch number:  22
# Training Set VAE loss:  tf.Tensor(43.01928, shape=(), dtype=float32)
# epoch number:  23
# Training Set VAE loss:  tf.Tensor(42.917625, shape=(), dtype=float32)
# epoch number:  24
# Training Set VAE loss:  tf.Tensor(42.924183, shape=(), dtype=float32)
# epoch number:  25
# Training Set VAE loss:  tf.Tensor(42.867153, shape=(), dtype=float32)
# epoch number:  26
# Training Set VAE loss:  tf.Tensor(42.886627, shape=(), dtype=float32)
# epoch number:  27
# Training Set VAE loss:  tf.Tensor(42.74262, shape=(), dtype=float32)
# epoch number:  28
# Training Set VAE loss:  tf.Tensor(42.789585, shape=(), dtype=float32)
# epoch number:  29
# Training Set VAE loss:  tf.Tensor(42.742928, shape=(), dtype=float32)
# epoch number:  30
# Training Set VAE loss:  tf.Tensor(42.64708, shape=(), dtype=float32)
# epoch number:  31
# Training Set VAE loss:  tf.Tensor(42.609165, shape=(), dtype=float32)
# epoch number:  32
# Training Set VAE loss:  tf.Tensor(42.66826, shape=(), dtype=float32)
# epoch number:  33
# Training Set VAE loss:  tf.Tensor(42.631756, shape=(), dtype=float32)
# epoch number:  34
# Training Set VAE loss:  tf.Tensor(42.602062, shape=(), dtype=float32)
# epoch number:  35
# Training Set VAE loss:  tf.Tensor(42.68236, shape=(), dtype=float32)
# epoch number:  36
# Training Set VAE loss:  tf.Tensor(42.647053, shape=(), dtype=float32)
# epoch number:  37
# Training Set VAE loss:  tf.Tensor(42.593563, shape=(), dtype=float32)
# epoch number:  38
# Training Set VAE loss:  tf.Tensor(42.570614, shape=(), dtype=float32)
# epoch number:  39
# Training Set VAE loss:  tf.Tensor(42.424038, shape=(), dtype=float32)
# epoch number:  40
# Training Set VAE loss:  tf.Tensor(42.35268, shape=(), dtype=float32)
# epoch number:  41
# Training Set VAE loss:  tf.Tensor(42.210644, shape=(), dtype=float32)
# epoch number:  42
# Training Set VAE loss:  tf.Tensor(42.34018, shape=(), dtype=float32)
# epoch number:  43
# Training Set VAE loss:  tf.Tensor(42.33036, shape=(), dtype=float32)
# epoch number:  44
# Training Set VAE loss:  tf.Tensor(42.20982, shape=(), dtype=float32)
# epoch number:  45
# Training Set VAE loss:  tf.Tensor(42.24495, shape=(), dtype=float32)
# epoch number:  46
# Training Set VAE loss:  tf.Tensor(41.99447, shape=(), dtype=float32)
# epoch number:  47
# Training Set VAE loss:  tf.Tensor(42.185764, shape=(), dtype=float32)
# epoch number:  48
# Training Set VAE loss:  tf.Tensor(41.988384, shape=(), dtype=float32)
# epoch number:  49
# Training Set VAE loss:  tf.Tensor(42.110016, shape=(), dtype=float32)
# epoch number:  50
# Training Set VAE loss:  tf.Tensor(41.97795, shape=(), dtype=float32)
# epoch number:  51
# Training Set VAE loss:  tf.Tensor(42.017696, shape=(), dtype=float32)
# epoch number:  52
# Training Set VAE loss:  tf.Tensor(41.8371, shape=(), dtype=float32)
# epoch number:  53
# Training Set VAE loss:  tf.Tensor(41.762516, shape=(), dtype=float32)
# epoch number:  54
# Training Set VAE loss:  tf.Tensor(41.825764, shape=(), dtype=float32)
# epoch number:  55
# Training Set VAE loss:  tf.Tensor(41.70056, shape=(), dtype=float32)
# epoch number:  56
# Training Set VAE loss:  tf.Tensor(41.486217, shape=(), dtype=float32)
# epoch number:  57
# Training Set VAE loss:  tf.Tensor(41.45078, shape=(), dtype=float32)
# epoch number:  58
# Training Set VAE loss:  tf.Tensor(41.525917, shape=(), dtype=float32)
# epoch number:  59
# Training Set VAE loss:  tf.Tensor(41.346638, shape=(), dtype=float32)
# epoch number:  60
# Training Set VAE loss:  tf.Tensor(41.464542, shape=(), dtype=float32)
# epoch number:  61
# Training Set VAE loss:  tf.Tensor(41.439896, shape=(), dtype=float32)
# epoch number:  62
# Training Set VAE loss:  tf.Tensor(41.23962, shape=(), dtype=float32)
# epoch number:  63
# Training Set VAE loss:  tf.Tensor(41.367554, shape=(), dtype=float32)
# epoch number:  64
# Training Set VAE loss:  tf.Tensor(41.307858, shape=(), dtype=float32)
# epoch number:  65
# Training Set VAE loss:  tf.Tensor(41.097385, shape=(), dtype=float32)
# epoch number:  66
# Training Set VAE loss:  tf.Tensor(40.999268, shape=(), dtype=float32)
# epoch number:  67
# Training Set VAE loss:  tf.Tensor(41.029766, shape=(), dtype=float32)
# epoch number:  68
# Training Set VAE loss:  tf.Tensor(41.000374, shape=(), dtype=float32)
# epoch number:  69
# Training Set VAE loss:  tf.Tensor(41.224777, shape=(), dtype=float32)
# epoch number:  70
# Training Set VAE loss:  tf.Tensor(40.947353, shape=(), dtype=float32)
# epoch number:  71
# Training Set VAE loss:  tf.Tensor(40.966717, shape=(), dtype=float32)
# epoch number:  72
# Training Set VAE loss:  tf.Tensor(40.85304, shape=(), dtype=float32)
# epoch number:  73
# Training Set VAE loss:  tf.Tensor(40.681316, shape=(), dtype=float32)
# epoch number:  74
# Training Set VAE loss:  tf.Tensor(40.76991, shape=(), dtype=float32)
# epoch number:  75
# Training Set VAE loss:  tf.Tensor(40.6859, shape=(), dtype=float32)
# epoch number:  76
# Training Set VAE loss:  tf.Tensor(40.73766, shape=(), dtype=float32)
# epoch number:  77
# Training Set VAE loss:  tf.Tensor(40.71504, shape=(), dtype=float32)
# epoch number:  78
# Training Set VAE loss:  tf.Tensor(40.541306, shape=(), dtype=float32)
# epoch number:  79
# Training Set VAE loss:  tf.Tensor(40.55562, shape=(), dtype=float32)
# epoch number:  80
# Training Set VAE loss:  tf.Tensor(40.699074, shape=(), dtype=float32)
# epoch number:  81
# Training Set VAE loss:  tf.Tensor(40.580658, shape=(), dtype=float32)
# epoch number:  82
# Training Set VAE loss:  tf.Tensor(40.416035, shape=(), dtype=float32)
# epoch number:  83
# Training Set VAE loss:  tf.Tensor(40.41307, shape=(), dtype=float32)
# epoch number:  84
# Training Set VAE loss:  tf.Tensor(40.52056, shape=(), dtype=float32)
# epoch number:  85
# Training Set VAE loss:  tf.Tensor(40.513496, shape=(), dtype=float32)
# epoch number:  86
# Training Set VAE loss:  tf.Tensor(40.561996, shape=(), dtype=float32)
# epoch number:  87
# Training Set VAE loss:  tf.Tensor(40.48506, shape=(), dtype=float32)
# epoch number:  88
# Training Set VAE loss:  tf.Tensor(40.32019, shape=(), dtype=float32)
# epoch number:  89
# Training Set VAE loss:  tf.Tensor(40.319893, shape=(), dtype=float32)
# epoch number:  90
# Training Set VAE loss:  tf.Tensor(40.396477, shape=(), dtype=float32)
# epoch number:  91
# Training Set VAE loss:  tf.Tensor(40.28268, shape=(), dtype=float32)
# epoch number:  92
# Training Set VAE loss:  tf.Tensor(40.245636, shape=(), dtype=float32)
# epoch number:  93
# Training Set VAE loss:  tf.Tensor(40.243053, shape=(), dtype=float32)
# epoch number:  94
# Training Set VAE loss:  tf.Tensor(40.254993, shape=(), dtype=float32)
# epoch number:  95
# Training Set VAE loss:  tf.Tensor(40.317104, shape=(), dtype=float32)
# epoch number:  96
# Training Set VAE loss:  tf.Tensor(40.24119, shape=(), dtype=float32)
# epoch number:  97
# Training Set VAE loss:  tf.Tensor(40.12828, shape=(), dtype=float32)
# epoch number:  98
# Training Set VAE loss:  tf.Tensor(40.146637, shape=(), dtype=float32)
# epoch number:  99
# Training Set VAE loss:  tf.Tensor(40.039696, shape=(), dtype=float32)
# epoch number:  100
# Training Set VAE loss:  tf.Tensor(40.226936, shape=(), dtype=float32)
# epoch number:  101
# Training Set VAE loss:  tf.Tensor(40.130257, shape=(), dtype=float32)
# epoch number:  102
# Training Set VAE loss:  tf.Tensor(40.302658, shape=(), dtype=float32)
# epoch number:  103
# Training Set VAE loss:  tf.Tensor(40.241486, shape=(), dtype=float32)
# epoch number:  104
# Training Set VAE loss:  tf.Tensor(40.28061, shape=(), dtype=float32)
# epoch number:  105
# Training Set VAE loss:  tf.Tensor(40.296547, shape=(), dtype=float32)
# epoch number:  106
# Training Set VAE loss:  tf.Tensor(40.25962, shape=(), dtype=float32)
# epoch number:  107
# Training Set VAE loss:  tf.Tensor(40.283394, shape=(), dtype=float32)
# epoch number:  108
# Training Set VAE loss:  tf.Tensor(40.30363, shape=(), dtype=float32)
# epoch number:  109
# Training Set VAE loss:  tf.Tensor(40.29977, shape=(), dtype=float32)
# epoch number:  110
# Training Set VAE loss:  tf.Tensor(40.12972, shape=(), dtype=float32)
# epoch number:  111
# Training Set VAE loss:  tf.Tensor(40.187202, shape=(), dtype=float32)
# epoch number:  112
# Training Set VAE loss:  tf.Tensor(40.154816, shape=(), dtype=float32)
# epoch number:  113
# Training Set VAE loss:  tf.Tensor(40.110397, shape=(), dtype=float32)
# epoch number:  114
# Training Set VAE loss:  tf.Tensor(40.216957, shape=(), dtype=float32)
# epoch number:  115
# Training Set VAE loss:  tf.Tensor(40.09543, shape=(), dtype=float32)
# epoch number:  116
# Training Set VAE loss:  tf.Tensor(40.018147, shape=(), dtype=float32)
# epoch number:  117
# Training Set VAE loss:  tf.Tensor(40.03388, shape=(), dtype=float32)
# epoch number:  118
# Training Set VAE loss:  tf.Tensor(40.046574, shape=(), dtype=float32)
# epoch number:  119
# Training Set VAE loss:  tf.Tensor(40.05755, shape=(), dtype=float32)
# epoch number:  120
# Training Set VAE loss:  tf.Tensor(40.034096, shape=(), dtype=float32)
# epoch number:  121
# Training Set VAE loss:  tf.Tensor(40.13271, shape=(), dtype=float32)
# epoch number:  122
# Training Set VAE loss:  tf.Tensor(40.16673, shape=(), dtype=float32)
# epoch number:  123
# Training Set VAE loss:  tf.Tensor(40.06806, shape=(), dtype=float32)
# epoch number:  124
# Training Set VAE loss:  tf.Tensor(40.116287, shape=(), dtype=float32)
# epoch number:  125
# Training Set VAE loss:  tf.Tensor(40.037342, shape=(), dtype=float32)
# epoch number:  126
# Training Set VAE loss:  tf.Tensor(40.10652, shape=(), dtype=float32)
# epoch number:  127
# Training Set VAE loss:  tf.Tensor(40.04699, shape=(), dtype=float32)
# epoch number:  128
# Training Set VAE loss:  tf.Tensor(40.032394, shape=(), dtype=float32)
# epoch number:  129
# Training Set VAE loss:  tf.Tensor(40.12556, shape=(), dtype=float32)
# epoch number:  130
# Training Set VAE loss:  tf.Tensor(40.08067, shape=(), dtype=float32)
# epoch number:  131
# Training Set VAE loss:  tf.Tensor(40.09482, shape=(), dtype=float32)
# epoch number:  132
# Training Set VAE loss:  tf.Tensor(40.036808, shape=(), dtype=float32)
# epoch number:  133
# Training Set VAE loss:  tf.Tensor(40.049854, shape=(), dtype=float32)
# epoch number:  134
# Training Set VAE loss:  tf.Tensor(40.016994, shape=(), dtype=float32)
# epoch number:  135
# Training Set VAE loss:  tf.Tensor(39.988335, shape=(), dtype=float32)
# epoch number:  136
# Training Set VAE loss:  tf.Tensor(39.96927, shape=(), dtype=float32)
# epoch number:  137
# Training Set VAE loss:  tf.Tensor(40.02449, shape=(), dtype=float32)
# epoch number:  138
# Training Set VAE loss:  tf.Tensor(39.982143, shape=(), dtype=float32)
# epoch number:  139
# Training Set VAE loss:  tf.Tensor(40.01018, shape=(), dtype=float32)
# epoch number:  140
# Training Set VAE loss:  tf.Tensor(39.984486, shape=(), dtype=float32)
# epoch number:  141
# Training Set VAE loss:  tf.Tensor(39.95171, shape=(), dtype=float32)
# epoch number:  142
# Training Set VAE loss:  tf.Tensor(39.91974, shape=(), dtype=float32)
# epoch number:  143
# Training Set VAE loss:  tf.Tensor(39.918694, shape=(), dtype=float32)
# epoch number:  144
# Training Set VAE loss:  tf.Tensor(39.91938, shape=(), dtype=float32)
# epoch number:  145
# Training Set VAE loss:  tf.Tensor(39.946854, shape=(), dtype=float32)
# epoch number:  146
# Training Set VAE loss:  tf.Tensor(39.963497, shape=(), dtype=float32)
# epoch number:  147
# Training Set VAE loss:  tf.Tensor(39.940147, shape=(), dtype=float32)
# epoch number:  148
# Training Set VAE loss:  tf.Tensor(39.999176, shape=(), dtype=float32)
# epoch number:  149
# Training Set VAE loss:  tf.Tensor(39.920235, shape=(), dtype=float32)
# epoch number:  150
# Training Set VAE loss:  tf.Tensor(39.901672, shape=(), dtype=float32)
# epoch number:  151
# Training Set VAE loss:  tf.Tensor(39.946465, shape=(), dtype=float32)
# epoch number:  152
# Training Set VAE loss:  tf.Tensor(39.938946, shape=(), dtype=float32)
# epoch number:  153
# Training Set VAE loss:  tf.Tensor(39.96543, shape=(), dtype=float32)
# epoch number:  154
# Training Set VAE loss:  tf.Tensor(39.962177, shape=(), dtype=float32)
# epoch number:  155
# Training Set VAE loss:  tf.Tensor(39.930428, shape=(), dtype=float32)
# epoch number:  156
# Training Set VAE loss:  tf.Tensor(39.910904, shape=(), dtype=float32)
# epoch number:  157
# Training Set VAE loss:  tf.Tensor(39.954803, shape=(), dtype=float32)
# epoch number:  158
# Training Set VAE loss:  tf.Tensor(39.992416, shape=(), dtype=float32)
# epoch number:  159
# Training Set VAE loss:  tf.Tensor(40.0409, shape=(), dtype=float32)
# epoch number:  160
# Training Set VAE loss:  tf.Tensor(39.9447, shape=(), dtype=float32)
# epoch number:  161
# Training Set VAE loss:  tf.Tensor(39.89988, shape=(), dtype=float32)
# epoch number:  162
# Training Set VAE loss:  tf.Tensor(39.880375, shape=(), dtype=float32)
# epoch number:  163
# Training Set VAE loss:  tf.Tensor(39.884346, shape=(), dtype=float32)
# epoch number:  164
# Training Set VAE loss:  tf.Tensor(39.903984, shape=(), dtype=float32)
# epoch number:  165
# Training Set VAE loss:  tf.Tensor(39.916, shape=(), dtype=float32)
# epoch number:  166
# Training Set VAE loss:  tf.Tensor(39.983166, shape=(), dtype=float32)
# epoch number:  167
# Training Set VAE loss:  tf.Tensor(39.92679, shape=(), dtype=float32)
# epoch number:  168
# Training Set VAE loss:  tf.Tensor(39.893177, shape=(), dtype=float32)
# epoch number:  169
# Training Set VAE loss:  tf.Tensor(39.878883, shape=(), dtype=float32)
# epoch number:  170
# Training Set VAE loss:  tf.Tensor(39.873745, shape=(), dtype=float32)
# epoch number:  171
# Training Set VAE loss:  tf.Tensor(39.875626, shape=(), dtype=float32)
# epoch number:  172
# Training Set VAE loss:  tf.Tensor(39.847694, shape=(), dtype=float32)
# epoch number:  173
# Training Set VAE loss:  tf.Tensor(39.86301, shape=(), dtype=float32)
# epoch number:  174
# Training Set VAE loss:  tf.Tensor(39.84216, shape=(), dtype=float32)
# epoch number:  175
# Training Set VAE loss:  tf.Tensor(39.842358, shape=(), dtype=float32)
# epoch number:  176
# Training Set VAE loss:  tf.Tensor(39.815216, shape=(), dtype=float32)
# epoch number:  177
# Training Set VAE loss:  tf.Tensor(39.808395, shape=(), dtype=float32)
# epoch number:  178
# Training Set VAE loss:  tf.Tensor(39.839542, shape=(), dtype=float32)
# epoch number:  179
# Training Set VAE loss:  tf.Tensor(39.822346, shape=(), dtype=float32)
# epoch number:  180
# Training Set VAE loss:  tf.Tensor(39.824165, shape=(), dtype=float32)
# epoch number:  181
# Training Set VAE loss:  tf.Tensor(39.788742, shape=(), dtype=float32)
# epoch number:  182
# Training Set VAE loss:  tf.Tensor(39.847656, shape=(), dtype=float32)
# epoch number:  183
# Training Set VAE loss:  tf.Tensor(39.82351, shape=(), dtype=float32)
# epoch number:  184
# Training Set VAE loss:  tf.Tensor(39.798332, shape=(), dtype=float32)
# epoch number:  185
# Training Set VAE loss:  tf.Tensor(39.77535, shape=(), dtype=float32)
# epoch number:  186
# Training Set VAE loss:  tf.Tensor(39.775925, shape=(), dtype=float32)
# epoch number:  187
# Training Set VAE loss:  tf.Tensor(39.77707, shape=(), dtype=float32)
# epoch number:  188
# Training Set VAE loss:  tf.Tensor(39.736275, shape=(), dtype=float32)
# epoch number:  189
# Training Set VAE loss:  tf.Tensor(39.782597, shape=(), dtype=float32)
# epoch number:  190
# Training Set VAE loss:  tf.Tensor(39.74953, shape=(), dtype=float32)
# epoch number:  191
# Training Set VAE loss:  tf.Tensor(39.805393, shape=(), dtype=float32)
# epoch number:  192
# Training Set VAE loss:  tf.Tensor(39.824448, shape=(), dtype=float32)
# epoch number:  193
# Training Set VAE loss:  tf.Tensor(39.78998, shape=(), dtype=float32)
# epoch number:  194
# Training Set VAE loss:  tf.Tensor(39.8174, shape=(), dtype=float32)
# epoch number:  195
# Training Set VAE loss:  tf.Tensor(39.81648, shape=(), dtype=float32)
# epoch number:  196
# Training Set VAE loss:  tf.Tensor(39.78226, shape=(), dtype=float32)
# epoch number:  197
# Training Set VAE loss:  tf.Tensor(39.809326, shape=(), dtype=float32)
# epoch number:  198
# Training Set VAE loss:  tf.Tensor(39.75731, shape=(), dtype=float32)
# epoch number:  199
# Training Set VAE loss:  tf.Tensor(39.774544, shape=(), dtype=float32)
# epoch number:  200
# Training Set VAE loss:  tf.Tensor(39.75133, shape=(), dtype=float32)
#
#  VAE_B training:
#
# epoch number:  1
# Training Set VAE loss:  tf.Tensor(30.008835, shape=(), dtype=float32)
# epoch number:  2
# Training Set VAE loss:  tf.Tensor(29.945045, shape=(), dtype=float32)
# epoch number:  3
# Training Set VAE loss:  tf.Tensor(29.962225, shape=(), dtype=float32)
# epoch number:  4
# Training Set VAE loss:  tf.Tensor(29.91183, shape=(), dtype=float32)
# epoch number:  5
# Training Set VAE loss:  tf.Tensor(29.901293, shape=(), dtype=float32)
# epoch number:  6
# Training Set VAE loss:  tf.Tensor(29.856298, shape=(), dtype=float32)
# epoch number:  7
# Training Set VAE loss:  tf.Tensor(29.914581, shape=(), dtype=float32)
# epoch number:  8
# Training Set VAE loss:  tf.Tensor(29.92976, shape=(), dtype=float32)
# epoch number:  9
# Training Set VAE loss:  tf.Tensor(29.921307, shape=(), dtype=float32)
# epoch number:  10
# Training Set VAE loss:  tf.Tensor(29.925694, shape=(), dtype=float32)
# epoch number:  11
# Training Set VAE loss:  tf.Tensor(29.932781, shape=(), dtype=float32)
# epoch number:  12
# Training Set VAE loss:  tf.Tensor(29.985825, shape=(), dtype=float32)
# epoch number:  13
# Training Set VAE loss:  tf.Tensor(29.924297, shape=(), dtype=float32)
# epoch number:  14
# Training Set VAE loss:  tf.Tensor(29.951141, shape=(), dtype=float32)
# epoch number:  15
# Training Set VAE loss:  tf.Tensor(29.87093, shape=(), dtype=float32)
# epoch number:  16
# Training Set VAE loss:  tf.Tensor(29.891888, shape=(), dtype=float32)
# epoch number:  17
# Training Set VAE loss:  tf.Tensor(29.855358, shape=(), dtype=float32)
# epoch number:  18
# Training Set VAE loss:  tf.Tensor(29.827686, shape=(), dtype=float32)
# epoch number:  19
# Training Set VAE loss:  tf.Tensor(29.811323, shape=(), dtype=float32)
# epoch number:  20
# Training Set VAE loss:  tf.Tensor(29.866604, shape=(), dtype=float32)
# epoch number:  21
# Training Set VAE loss:  tf.Tensor(29.839241, shape=(), dtype=float32)
# epoch number:  22
# Training Set VAE loss:  tf.Tensor(29.808905, shape=(), dtype=float32)
# epoch number:  23
# Training Set VAE loss:  tf.Tensor(29.76479, shape=(), dtype=float32)
# epoch number:  24
# Training Set VAE loss:  tf.Tensor(29.73759, shape=(), dtype=float32)
# epoch number:  25
# Training Set VAE loss:  tf.Tensor(29.839329, shape=(), dtype=float32)
# epoch number:  26
# Training Set VAE loss:  tf.Tensor(29.838184, shape=(), dtype=float32)
# epoch number:  27
# Training Set VAE loss:  tf.Tensor(29.81234, shape=(), dtype=float32)
# epoch number:  28
# Training Set VAE loss:  tf.Tensor(29.855907, shape=(), dtype=float32)
# epoch number:  29
# Training Set VAE loss:  tf.Tensor(29.872173, shape=(), dtype=float32)
# epoch number:  30
# Training Set VAE loss:  tf.Tensor(29.877205, shape=(), dtype=float32)
# epoch number:  31
# Training Set VAE loss:  tf.Tensor(29.859291, shape=(), dtype=float32)
# epoch number:  32
# Training Set VAE loss:  tf.Tensor(29.82111, shape=(), dtype=float32)
# epoch number:  33
# Training Set VAE loss:  tf.Tensor(29.816883, shape=(), dtype=float32)
# epoch number:  34
# Training Set VAE loss:  tf.Tensor(29.839558, shape=(), dtype=float32)
# epoch number:  35
# Training Set VAE loss:  tf.Tensor(29.778, shape=(), dtype=float32)
# epoch number:  36
# Training Set VAE loss:  tf.Tensor(29.830399, shape=(), dtype=float32)
# epoch number:  37
# Training Set VAE loss:  tf.Tensor(29.772236, shape=(), dtype=float32)
# epoch number:  38
# Training Set VAE loss:  tf.Tensor(29.7746, shape=(), dtype=float32)
# epoch number:  39
# Training Set VAE loss:  tf.Tensor(29.737457, shape=(), dtype=float32)
# epoch number:  40
# Training Set VAE loss:  tf.Tensor(29.688549, shape=(), dtype=float32)
# epoch number:  41
# Training Set VAE loss:  tf.Tensor(29.741842, shape=(), dtype=float32)
# epoch number:  42
# Training Set VAE loss:  tf.Tensor(29.609322, shape=(), dtype=float32)
# epoch number:  43
# Training Set VAE loss:  tf.Tensor(29.640026, shape=(), dtype=float32)
# epoch number:  44
# Training Set VAE loss:  tf.Tensor(29.705345, shape=(), dtype=float32)
# epoch number:  45
# Training Set VAE loss:  tf.Tensor(29.636904, shape=(), dtype=float32)
# epoch number:  46
# Training Set VAE loss:  tf.Tensor(29.635927, shape=(), dtype=float32)
# epoch number:  47
# Training Set VAE loss:  tf.Tensor(29.58792, shape=(), dtype=float32)
# epoch number:  48
# Training Set VAE loss:  tf.Tensor(29.570099, shape=(), dtype=float32)
# epoch number:  49
# Training Set VAE loss:  tf.Tensor(29.550373, shape=(), dtype=float32)
# epoch number:  50
# Training Set VAE loss:  tf.Tensor(29.455353, shape=(), dtype=float32)
# epoch number:  51
# Training Set VAE loss:  tf.Tensor(29.509209, shape=(), dtype=float32)
# epoch number:  52
# Training Set VAE loss:  tf.Tensor(29.472065, shape=(), dtype=float32)
# epoch number:  53
# Training Set VAE loss:  tf.Tensor(29.490028, shape=(), dtype=float32)
# epoch number:  54
# Training Set VAE loss:  tf.Tensor(29.416733, shape=(), dtype=float32)
# epoch number:  55
# Training Set VAE loss:  tf.Tensor(29.387608, shape=(), dtype=float32)
# epoch number:  56
# Training Set VAE loss:  tf.Tensor(29.517105, shape=(), dtype=float32)
# epoch number:  57
# Training Set VAE loss:  tf.Tensor(29.292933, shape=(), dtype=float32)
# epoch number:  58
# Training Set VAE loss:  tf.Tensor(29.508015, shape=(), dtype=float32)
# epoch number:  59
# Training Set VAE loss:  tf.Tensor(29.425755, shape=(), dtype=float32)
# epoch number:  60
# Training Set VAE loss:  tf.Tensor(29.35056, shape=(), dtype=float32)
# epoch number:  61
# Training Set VAE loss:  tf.Tensor(29.319195, shape=(), dtype=float32)
# epoch number:  62
# Training Set VAE loss:  tf.Tensor(29.172169, shape=(), dtype=float32)
# epoch number:  63
# Training Set VAE loss:  tf.Tensor(29.144, shape=(), dtype=float32)
# epoch number:  64
# Training Set VAE loss:  tf.Tensor(29.21753, shape=(), dtype=float32)
# epoch number:  65
# Training Set VAE loss:  tf.Tensor(29.148476, shape=(), dtype=float32)
# epoch number:  66
# Training Set VAE loss:  tf.Tensor(29.185402, shape=(), dtype=float32)
# epoch number:  67
# Training Set VAE loss:  tf.Tensor(29.136612, shape=(), dtype=float32)
# epoch number:  68
# Training Set VAE loss:  tf.Tensor(29.101065, shape=(), dtype=float32)
# epoch number:  69
# Training Set VAE loss:  tf.Tensor(29.136433, shape=(), dtype=float32)
# epoch number:  70
# Training Set VAE loss:  tf.Tensor(29.016743, shape=(), dtype=float32)
# epoch number:  71
# Training Set VAE loss:  tf.Tensor(29.145016, shape=(), dtype=float32)
# epoch number:  72
# Training Set VAE loss:  tf.Tensor(29.046593, shape=(), dtype=float32)
# epoch number:  73
# Training Set VAE loss:  tf.Tensor(28.896374, shape=(), dtype=float32)
# epoch number:  74
# Training Set VAE loss:  tf.Tensor(28.912651, shape=(), dtype=float32)
# epoch number:  75
# Training Set VAE loss:  tf.Tensor(28.871902, shape=(), dtype=float32)
# epoch number:  76
# Training Set VAE loss:  tf.Tensor(28.795218, shape=(), dtype=float32)
# epoch number:  77
# Training Set VAE loss:  tf.Tensor(28.730114, shape=(), dtype=float32)
# epoch number:  78
# Training Set VAE loss:  tf.Tensor(28.71651, shape=(), dtype=float32)
# epoch number:  79
# Training Set VAE loss:  tf.Tensor(28.71995, shape=(), dtype=float32)
# epoch number:  80
# Training Set VAE loss:  tf.Tensor(28.745056, shape=(), dtype=float32)
# epoch number:  81
# Training Set VAE loss:  tf.Tensor(28.693073, shape=(), dtype=float32)
# epoch number:  82
# Training Set VAE loss:  tf.Tensor(28.734009, shape=(), dtype=float32)
# epoch number:  83
# Training Set VAE loss:  tf.Tensor(28.690762, shape=(), dtype=float32)
# epoch number:  84
# Training Set VAE loss:  tf.Tensor(28.53637, shape=(), dtype=float32)
# epoch number:  85
# Training Set VAE loss:  tf.Tensor(28.573214, shape=(), dtype=float32)
# epoch number:  86
# Training Set VAE loss:  tf.Tensor(28.538296, shape=(), dtype=float32)
# epoch number:  87
# Training Set VAE loss:  tf.Tensor(28.504436, shape=(), dtype=float32)
# epoch number:  88
# Training Set VAE loss:  tf.Tensor(28.630611, shape=(), dtype=float32)
# epoch number:  89
# Training Set VAE loss:  tf.Tensor(28.581467, shape=(), dtype=float32)
# epoch number:  90
# Training Set VAE loss:  tf.Tensor(28.594307, shape=(), dtype=float32)
# epoch number:  91
# Training Set VAE loss:  tf.Tensor(28.497936, shape=(), dtype=float32)
# epoch number:  92
# Training Set VAE loss:  tf.Tensor(28.50184, shape=(), dtype=float32)
# epoch number:  93
# Training Set VAE loss:  tf.Tensor(28.486282, shape=(), dtype=float32)
# epoch number:  94
# Training Set VAE loss:  tf.Tensor(28.371523, shape=(), dtype=float32)
# epoch number:  95
# Training Set VAE loss:  tf.Tensor(28.5201, shape=(), dtype=float32)
# epoch number:  96
# Training Set VAE loss:  tf.Tensor(28.40158, shape=(), dtype=float32)
# epoch number:  97
# Training Set VAE loss:  tf.Tensor(28.373035, shape=(), dtype=float32)
# epoch number:  98
# Training Set VAE loss:  tf.Tensor(28.461355, shape=(), dtype=float32)
# epoch number:  99
# Training Set VAE loss:  tf.Tensor(28.346992, shape=(), dtype=float32)
# epoch number:  100
# Training Set VAE loss:  tf.Tensor(28.426968, shape=(), dtype=float32)
# epoch number:  101
# Training Set VAE loss:  tf.Tensor(28.339588, shape=(), dtype=float32)
# epoch number:  102
# Training Set VAE loss:  tf.Tensor(28.333694, shape=(), dtype=float32)
# epoch number:  103
# Training Set VAE loss:  tf.Tensor(28.25341, shape=(), dtype=float32)
# epoch number:  104
# Training Set VAE loss:  tf.Tensor(28.313374, shape=(), dtype=float32)
# epoch number:  105
# Training Set VAE loss:  tf.Tensor(28.26524, shape=(), dtype=float32)
# epoch number:  106
# Training Set VAE loss:  tf.Tensor(28.24821, shape=(), dtype=float32)
# epoch number:  107
# Training Set VAE loss:  tf.Tensor(28.140385, shape=(), dtype=float32)
# epoch number:  108
# Training Set VAE loss:  tf.Tensor(28.190037, shape=(), dtype=float32)
# epoch number:  109
# Training Set VAE loss:  tf.Tensor(28.369492, shape=(), dtype=float32)
# epoch number:  110
# Training Set VAE loss:  tf.Tensor(28.373857, shape=(), dtype=float32)
# epoch number:  111
# Training Set VAE loss:  tf.Tensor(28.314987, shape=(), dtype=float32)
# epoch number:  112
# Training Set VAE loss:  tf.Tensor(28.401749, shape=(), dtype=float32)
# epoch number:  113
# Training Set VAE loss:  tf.Tensor(28.166386, shape=(), dtype=float32)
# epoch number:  114
# Training Set VAE loss:  tf.Tensor(28.266064, shape=(), dtype=float32)
# epoch number:  115
# Training Set VAE loss:  tf.Tensor(28.176826, shape=(), dtype=float32)
# epoch number:  116
# Training Set VAE loss:  tf.Tensor(28.229584, shape=(), dtype=float32)
# epoch number:  117
# Training Set VAE loss:  tf.Tensor(28.193542, shape=(), dtype=float32)
# epoch number:  118
# Training Set VAE loss:  tf.Tensor(28.156702, shape=(), dtype=float32)
# epoch number:  119
# Training Set VAE loss:  tf.Tensor(28.198849, shape=(), dtype=float32)
# epoch number:  120
# Training Set VAE loss:  tf.Tensor(28.158281, shape=(), dtype=float32)
# epoch number:  121
# Training Set VAE loss:  tf.Tensor(28.281921, shape=(), dtype=float32)
# epoch number:  122
# Training Set VAE loss:  tf.Tensor(28.193542, shape=(), dtype=float32)
# epoch number:  123
# Training Set VAE loss:  tf.Tensor(28.190897, shape=(), dtype=float32)
# epoch number:  124
# Training Set VAE loss:  tf.Tensor(28.210526, shape=(), dtype=float32)
# epoch number:  125
# Training Set VAE loss:  tf.Tensor(28.28915, shape=(), dtype=float32)
# epoch number:  126
# Training Set VAE loss:  tf.Tensor(28.07993, shape=(), dtype=float32)
# epoch number:  127
# Training Set VAE loss:  tf.Tensor(28.111275, shape=(), dtype=float32)
# epoch number:  128
# Training Set VAE loss:  tf.Tensor(28.052477, shape=(), dtype=float32)
# epoch number:  129
# Training Set VAE loss:  tf.Tensor(28.062141, shape=(), dtype=float32)
# epoch number:  130
# Training Set VAE loss:  tf.Tensor(28.244993, shape=(), dtype=float32)
# epoch number:  131
# Training Set VAE loss:  tf.Tensor(27.965084, shape=(), dtype=float32)
# epoch number:  132
# Training Set VAE loss:  tf.Tensor(28.169716, shape=(), dtype=float32)
# epoch number:  133
# Training Set VAE loss:  tf.Tensor(28.015816, shape=(), dtype=float32)
# epoch number:  134
# Training Set VAE loss:  tf.Tensor(27.975231, shape=(), dtype=float32)
# epoch number:  135
# Training Set VAE loss:  tf.Tensor(27.909832, shape=(), dtype=float32)
# epoch number:  136
# Training Set VAE loss:  tf.Tensor(28.053358, shape=(), dtype=float32)
# epoch number:  137
# Training Set VAE loss:  tf.Tensor(28.006895, shape=(), dtype=float32)
# epoch number:  138
# Training Set VAE loss:  tf.Tensor(27.920372, shape=(), dtype=float32)
# epoch number:  139
# Training Set VAE loss:  tf.Tensor(28.003298, shape=(), dtype=float32)
# epoch number:  140
# Training Set VAE loss:  tf.Tensor(27.836555, shape=(), dtype=float32)
# epoch number:  141
# Training Set VAE loss:  tf.Tensor(27.820152, shape=(), dtype=float32)
# epoch number:  142
# Training Set VAE loss:  tf.Tensor(27.796505, shape=(), dtype=float32)
# epoch number:  143
# Training Set VAE loss:  tf.Tensor(27.796291, shape=(), dtype=float32)
# epoch number:  144
# Training Set VAE loss:  tf.Tensor(27.882782, shape=(), dtype=float32)
# epoch number:  145
# Training Set VAE loss:  tf.Tensor(27.761475, shape=(), dtype=float32)
# epoch number:  146
# Training Set VAE loss:  tf.Tensor(27.786568, shape=(), dtype=float32)
# epoch number:  147
# Training Set VAE loss:  tf.Tensor(27.858006, shape=(), dtype=float32)
# epoch number:  148
# Training Set VAE loss:  tf.Tensor(27.798882, shape=(), dtype=float32)
# epoch number:  149
# Training Set VAE loss:  tf.Tensor(27.797577, shape=(), dtype=float32)
# epoch number:  150
# Training Set VAE loss:  tf.Tensor(27.933596, shape=(), dtype=float32)
# epoch number:  151
# Training Set VAE loss:  tf.Tensor(27.864426, shape=(), dtype=float32)
# epoch number:  152
# Training Set VAE loss:  tf.Tensor(27.87754, shape=(), dtype=float32)
# epoch number:  153
# Training Set VAE loss:  tf.Tensor(27.813072, shape=(), dtype=float32)
# epoch number:  154
# Training Set VAE loss:  tf.Tensor(27.9432, shape=(), dtype=float32)
# epoch number:  155
# Training Set VAE loss:  tf.Tensor(27.874489, shape=(), dtype=float32)
# epoch number:  156
# Training Set VAE loss:  tf.Tensor(27.91425, shape=(), dtype=float32)
# epoch number:  157
# Training Set VAE loss:  tf.Tensor(27.874897, shape=(), dtype=float32)
# epoch number:  158
# Training Set VAE loss:  tf.Tensor(28.04192, shape=(), dtype=float32)
# epoch number:  159
# Training Set VAE loss:  tf.Tensor(27.833288, shape=(), dtype=float32)
# epoch number:  160
# Training Set VAE loss:  tf.Tensor(27.898434, shape=(), dtype=float32)
# epoch number:  161
# Training Set VAE loss:  tf.Tensor(27.941544, shape=(), dtype=float32)
# epoch number:  162
# Training Set VAE loss:  tf.Tensor(27.853771, shape=(), dtype=float32)
# epoch number:  163
# Training Set VAE loss:  tf.Tensor(27.964233, shape=(), dtype=float32)
# epoch number:  164
# Training Set VAE loss:  tf.Tensor(27.8602, shape=(), dtype=float32)
# epoch number:  165
# Training Set VAE loss:  tf.Tensor(27.889404, shape=(), dtype=float32)
# epoch number:  166
# Training Set VAE loss:  tf.Tensor(27.880646, shape=(), dtype=float32)
# epoch number:  167
# Training Set VAE loss:  tf.Tensor(27.850365, shape=(), dtype=float32)
# epoch number:  168
# Training Set VAE loss:  tf.Tensor(27.838028, shape=(), dtype=float32)
# epoch number:  169
# Training Set VAE loss:  tf.Tensor(27.84137, shape=(), dtype=float32)
# epoch number:  170
# Training Set VAE loss:  tf.Tensor(27.890785, shape=(), dtype=float32)
# epoch number:  171
# Training Set VAE loss:  tf.Tensor(27.866901, shape=(), dtype=float32)
# epoch number:  172
# Training Set VAE loss:  tf.Tensor(27.895094, shape=(), dtype=float32)
# epoch number:  173
# Training Set VAE loss:  tf.Tensor(27.858624, shape=(), dtype=float32)
# epoch number:  174
# Training Set VAE loss:  tf.Tensor(27.855362, shape=(), dtype=float32)
# epoch number:  175
# Training Set VAE loss:  tf.Tensor(27.810125, shape=(), dtype=float32)
# epoch number:  176
# Training Set VAE loss:  tf.Tensor(27.841358, shape=(), dtype=float32)
# epoch number:  177
# Training Set VAE loss:  tf.Tensor(27.88733, shape=(), dtype=float32)
# epoch number:  178
# Training Set VAE loss:  tf.Tensor(27.876482, shape=(), dtype=float32)
# epoch number:  179
# Training Set VAE loss:  tf.Tensor(27.867191, shape=(), dtype=float32)
# epoch number:  180
# Training Set VAE loss:  tf.Tensor(27.875927, shape=(), dtype=float32)
# epoch number:  181
# Training Set VAE loss:  tf.Tensor(27.795774, shape=(), dtype=float32)
# epoch number:  182
# Training Set VAE loss:  tf.Tensor(27.85625, shape=(), dtype=float32)
# epoch number:  183
# Training Set VAE loss:  tf.Tensor(27.854641, shape=(), dtype=float32)
# epoch number:  184
# Training Set VAE loss:  tf.Tensor(27.829926, shape=(), dtype=float32)
# epoch number:  185
# Training Set VAE loss:  tf.Tensor(27.888683, shape=(), dtype=float32)
# epoch number:  186
# Training Set VAE loss:  tf.Tensor(27.815926, shape=(), dtype=float32)
# epoch number:  187
# Training Set VAE loss:  tf.Tensor(27.840504, shape=(), dtype=float32)
# epoch number:  188
# Training Set VAE loss:  tf.Tensor(27.848526, shape=(), dtype=float32)
# epoch number:  189
# Training Set VAE loss:  tf.Tensor(27.797878, shape=(), dtype=float32)
# epoch number:  190
# Training Set VAE loss:  tf.Tensor(27.829807, shape=(), dtype=float32)
# epoch number:  191
# Training Set VAE loss:  tf.Tensor(27.89663, shape=(), dtype=float32)
# epoch number:  192
# Training Set VAE loss:  tf.Tensor(27.823048, shape=(), dtype=float32)
# epoch number:  193
# Training Set VAE loss:  tf.Tensor(27.870323, shape=(), dtype=float32)
# epoch number:  194
# Training Set VAE loss:  tf.Tensor(27.83774, shape=(), dtype=float32)
# epoch number:  195
# Training Set VAE loss:  tf.Tensor(27.856266, shape=(), dtype=float32)
# epoch number:  196
# Training Set VAE loss:  tf.Tensor(27.854746, shape=(), dtype=float32)
# epoch number:  197
# Training Set VAE loss:  tf.Tensor(27.890781, shape=(), dtype=float32)
# epoch number:  198
# Training Set VAE loss:  tf.Tensor(27.803059, shape=(), dtype=float32)
# epoch number:  199
# Training Set VAE loss:  tf.Tensor(27.797138, shape=(), dtype=float32)
# epoch number:  200
# Training Set VAE loss:  tf.Tensor(27.787601, shape=(), dtype=float32)
# INFO:tensorflow:Assets written to: /Users/ahmedaly/Desktop/Final_Model/VAE_A/assets
# INFO:tensorflow:Assets written to: /Users/ahmedaly/Desktop/Final_Model/VAE_B/assets
# 2023-07-26 02:43:11.673075: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
import numpy as np
import math as m

# %%
def user_top_predictions(y, Rating_Matrix, k):#y is a tensor, and dataframe is its associated dataframe
    
    user_highest_predicted_movies = np.empty((y.shape[0], k))
    
    MovieIDs = Rating_Matrix.columns.tolist()
    
    list_UserIDs = Rating_Matrix.index.tolist()
    
    i = 0
    
    all_Movie_indices = np.empty((y.shape[0], k))
    
    UserIDs = np.empty(y.shape[0])
    
    for click_vector in y:
        
        highest_predicted_scores, indices_of_highest_scores = tf.math.top_k(click_vector, k)
        
        UserIDs[i] = list_UserIDs[i]
        
        Movie_indices = [MovieIDs[id] for id in indices_of_highest_scores]
    
        user_highest_predicted_movies[i] = Movie_indices
        
        all_Movie_indices[i] = indices_of_highest_scores
        
        i += 1
    
    all_Movie_indices = [[int(x) for x in row] for row in all_Movie_indices]
    
    return user_highest_predicted_movies, all_Movie_indices, UserIDs

# %%
def calc_recall(top_k_movies_IDs, Rating_Matrix, all_Movie_indices):
        
    recall = 0
    
    for i in range(len(top_k_movies_IDs)):
        
        MovieIDs = top_k_movies_IDs[i]
        
        columns_greater_than_threshold = Rating_Matrix.iloc[i] > 3
        
        number_of_relevant_items = columns_greater_than_threshold.sum()
        
        if number_of_relevant_items == 0:
            
            continue
            
        columns_greater_than_threshold_2 = Rating_Matrix.iloc[i , all_Movie_indices[i]] > 3
        
        recommended_relevant_items = columns_greater_than_threshold_2.sum()
        
        user_recall = recommended_relevant_items/number_of_relevant_items
        
        recall = recall + user_recall 
    
    recall = recall/len(top_k_movies_IDs)
         
    return recall

# %%
def calc_precision(top_k_movies_IDs, Rating_Matrix, all_Movie_indices):
    
    k = top_k_movies_IDs.shape[1]
    
    precision = 0
    
    for i in range(len(top_k_movies_IDs)):
        
        user_movie_indices = all_Movie_indices[i]
        
        recommended_relevant_movies = Rating_Matrix.iloc[i, user_movie_indices] > 3
        
        number_recommended_relevant_movies = recommended_relevant_movies.sum()
        
        user_precision = number_recommended_relevant_movies/k
        
        precision = precision + user_precision
    
    precision = precision/len(top_k_movies_IDs)
    
    return precision

# %%
def calc_NDCG(all_Movie_indices, Rating_Matrix):
        
    DCG = 0
    
    IDCG = 0
    
    NDCG = 0
    
    for i in range(len(all_Movie_indices)):
        
        row = all_Movie_indices[i]
        
        for j in row:
            
            relevance = Rating_Matrix.iloc[i,j]
            
            user_dcg = relevance/m.log(j + 2, 2)
            
            DCG = DCG + user_dcg
    
    for k in range(len(all_Movie_indices)):
        
        df = Rating_Matrix.iloc[k,all_Movie_indices[k]]
        
        row_arr = np.array(df)
        
        row_arr = sorted(row_arr, reverse = True)
        
        for l in range(len(row_arr)):
            
            user_idcg = row_arr[l]/m.log(l + 2, 2)
            
            IDCG = IDCG + user_idcg
    
    NDCG = DCG/IDCG
    
    return NDCG

# %%
def Average_MSE (Rating_Matrix, y):#go back and modify the reconstruction loss to MSE in the loss function (maybe)
    
    rating_matrix = Rating_Matrix.to_numpy()
    
    y_numpy = y.numpy()
    
    MSE_arr = np.square(rating_matrix - y_numpy)
    
    MSE = np.sum(MSE_arr) / rating_matrix.size
    
    return MSE

# %%
print("Recall AA: \n")
for k in range(36, 361, 36):

    user_highest_predicted_movies_AA, all_Movie_indices_AA, user_IDs_AA = user_top_predictions(y_AA, DomainA_test_1, k)
    recall_AA = calc_recall(user_highest_predicted_movies_AA, DomainA_test_1, all_Movie_indices_AA)
    
    print(recall_AA)

print("NDCG AA: \n")
for k in range(36, 361, 36):
    user_highest_predicted_movies_AA, all_Movie_indices_AA, user_IDs_AA = user_top_predictions(y_AA, DomainA_test_1, k)
    NDCG_AA = calc_NDCG(all_Movie_indices_AA, DomainA_test_1) 

    print(NDCG_AA)
# Out:
# Recall AA:
#
# 0.3661440919645031
# 0.577096845770239
# 0.6974443289060134
# 0.7780790106724497
# 0.8213574703787098
# 0.8552197251850623
# 0.8990957995802563
# 0.9300997868313318
# 0.9494010536971972
# 0.9598478973737568
# NDCG AA:
#
# 0.4160379879547238
# 0.49252048256457204
# 0.5233985709327116
# 0.5411832480065166
# 0.5580655412193836
# 0.5664880524844443
# 0.5708976742106414
# 0.5741563594105837
# 0.5766020128702879
# 0.5781432720861873

# %%
print("Precision AA: \n")

for k in range(5, 51, 5):
    
    user_highest_predicted_movies_AA, all_Movie_indices_AA, user_IDs_AA = user_top_predictions(y_AA, DomainA_test_1, k)
    precision_AA = calc_precision(user_highest_predicted_movies_AA, DomainA_test_1, all_Movie_indices_AA)

    #print('\nFor k =, ', k)
    #print('Precision for AA:', precision_AA)
    print(precision_AA)
# Out:
# Precision AA:
#
# 0.28865248226950385
# 0.26134751773049647
# 0.2527186761229319
# 0.23865248226950334
# 0.22709219858155996
# 0.21501182033096916
# 0.20678824721377934
# 0.20017730496453898
# 0.19637509850275833
# 0.19170212765957442

# %%
print("Recall BB: \n")
for k in range(25, 251, 25):

    user_highest_predicted_movies_BB, all_Movie_indices_BB, user_IDs_BB = user_top_predictions(y_BB, DomainB_test_1, k)
    recall_BB = calc_recall(user_highest_predicted_movies_BB, DomainB_test_1, all_Movie_indices_BB)
    
    print(recall_BB)

print("NDCG BB: \n")
for k in range(25, 251, 25):
    user_highest_predicted_movies_BB, all_Movie_indices_BB, user_IDs_BB = user_top_predictions(y_BB, DomainB_test_1, k)
    NDCG_BB = calc_NDCG(all_Movie_indices_BB, DomainB_test_1) 

    print(NDCG_BB)
# Out:
# Recall BB:
#
# 0.28758044543936473
# 0.4762260093090494
# 0.5961767230271268
# 0.7124741152617787
# 0.7791587189548836
# 0.8248474829156656
# 0.8556530627640693
# 0.8832676005056639
# 0.9118228417302743
# 0.9273507729101311
# NDCG BB:
#
# 0.47453684733945706
# 0.5252758137297806
# 0.5474362343558469
# 0.5610914107534194
# 0.5753185223458219
# 0.5825015389212249
# 0.587279227205097
# 0.5900664124460667
# 0.5905773844397425
# 0.5919695825177406

# %%
print("Precision BB: \n")

for k in range(5, 51, 5):
    
    user_highest_predicted_movies_BB, all_Movie_indices_BB, user_IDs_BB = user_top_predictions(y_BB, DomainB_test_1, k)
    precision_BB = calc_precision(user_highest_predicted_movies_BB, DomainB_test_1, all_Movie_indices_BB)

    #print('\nFor k =, ', k)
    #print('Precision for BB:', precision_BB)
    print(precision_BB)
# Out:
# Precision BB:
#
# 0.21773049645390108
# 0.1975177304964541
# 0.18510638297872395
# 0.1739361702127658
# 0.16595744680851024
# 0.1607565011820333
# 0.15521783181357665
# 0.15106382978723393
# 0.14728132387706877
# 0.14262411347517734

# %%
MSE_AA = Average_MSE(DomainA_test_2, y_AA)
MSE_BB = Average_MSE(DomainB_test_2, y_BB)

# %%
print('Average MSE_AA: ', MSE_AA)
print('Average MSE_BB: ', MSE_BB)
# Out:
# Average MSE_AA:  0.22343945461405784
# Average MSE_BB:  0.22744421321719316

# %%
def inject_fake_interactions(interaction_matrix):
    
    injected_interaction_matrix = interaction_matrix.copy()
    
    for column in interaction_matrix.columns:
        
        injected_interaction_matrix[column] = interaction_matrix[column].apply(
            lambda x: 1 - x if np.random.random() > 0.1 else x)
    
    fake_interaction_matrix = tf.cast(injected_interaction_matrix, tf.float32)
    
    return fake_interaction_matrix

#np.random.random() > 0.1 for ML1M 
#np.random.random() > 0.5 for ML100K

# %%
domainA_test_injected = inject_fake_interactions(DomainA_test_2)

domainB_test_injected = inject_fake_interactions(DomainB_test_2)

y_AA_injected, y_BB_injected = load_and_test(domainA_test_injected, domainB_test_injected, '/Users/ahmedaly/Desktop/Final_Model/VAE_A', 
              '/Users/ahmedaly/Desktop/Final_Model/VAE_B')

# %%
MSE_AA_injected = Average_MSE(DomainA_test_2, y_AA_injected)
MSE_BB_injected = Average_MSE(DomainB_test_2, y_BB_injected)

# %%
print('Average MSE_AA: ', MSE_AA_injected)
print('Average MSE_BB: ', MSE_BB_injected)
# Out:
# Average MSE_AA:  0.24325357019612348
# Average MSE_BB:  0.2566139991085023
